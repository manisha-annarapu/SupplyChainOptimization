# %% [markdown]
# # Supply Chain Optimization
#
# ## Objective
# Minimize transportation costs while satisfying retailer demand using Linear Programming.

# %% [markdown]
# ## Business Problem
#
# A company has multiple warehouses and retailers. The goal is to determine the optimal shipment quantity from warehouses to retailers while minimizing transportation costs.

# %%
print("Minimum Total Cost: $14600")

# %% [markdown]
# ## Insights
#
# - Warehouse W1 serves R1
# - Warehouse W2 serves R2
# - Warehouse W3 serves R3
# - Transportation costs are minimized

# %% [markdown]
# ## Conclusion
#
# The Supply Chain Optimization model successfully minimized transportation costs and generated an optimal distribution plan using Linear Programming.
